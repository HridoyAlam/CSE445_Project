# %%
import sys
import numpy
import pandas
import matplotlib
import seaborn
import scipy
import sklearn

print("Python: {}".format(sys.version))
print("Numpy: {}".format(numpy.__version__))
# Out:
# Python: 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]
# Numpy: 1.15.4

# %%
#import the necessary packages and giving them names

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading the dataset

data = pd.read_csv('dataBlock.csv',dtype={"ZIP CODE": str})

# %%
data.columns
# Out:
# Index(['DATE', 'TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE', 'LONGITUDE',
#        'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME', 'OFF STREET NAME',
#        'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
#        'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
#        'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
#        'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED',
#        'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2',
#        'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4',
#        'CONTRIBUTING FACTOR VEHICLE 5', 'UNIQUE KEY', 'VEHICLE TYPE CODE 1',
#        'VEHICLE TYPE CODE 2', 'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4',
#        'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
data.head()
# Out:
#       DATE  TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  3/24/19  0:00  BROOKLYN    11204  40.619130  -73.99019
# 1  3/24/19  0:00  BROOKLYN    11213  40.668648  -73.92835
# 2  3/24/19  0:00  BROOKLYN    11229  40.599144  -73.95356
# 3  3/24/19  0:00  BROOKLYN    11229  40.609130  -73.95741
# 4  3/24/19  0:00  BROOKLYN    11229  40.604027  -73.95230
#
#                  LOCATION                    ON STREET NAME CROSS STREET NAME  \
# 0   (40.61913, -73.99019)  65 STREET                                18 AVENUE
# 1  (40.668648, -73.92835)  ROCHESTER AVENUE                   EASTERN PARKWAY
# 2  (40.599144, -73.95356)  AVENUE U                            EAST 18 STREET
# 3   (40.60913, -73.95741)  EAST 16 STREET                       KINGS HIGHWAY
# 4   (40.604027, -73.9523)  OCEAN AVENUE                              AVENUE S
#
#   OFF STREET NAME         ...           CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN         ...                             Unspecified
# ...

# %%
data.tail()
# Out:
#             DATE   TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 1048570  7/23/14  20:15     BRONX    10471  40.904446 -73.902648
# 1048571  7/23/14  20:19       NaN      NaN        NaN        NaN
# 1048572  7/23/14  20:21    QUEENS    11368  40.748843 -73.862952
# 1048573  7/23/14  20:28  BROOKLYN    11217  40.683514 -73.975951
# 1048574  7/23/14  20:30    QUEENS    11411  40.688884 -73.738319
#
#                           LOCATION                    ON STREET NAME  \
# 1048570  (40.9044455, -73.9026482)  MOSHOLU AVENUE
# 1048571                        NaN  50 AVENUE
# 1048572  (40.7488428, -73.8629517)  103 STREET
# 1048573  (40.6835142, -73.9759509)  ATLANTIC AVENUE
# 1048574  (40.6888844, -73.7383194)  120 AVENUE
#
#                         CROSS STREET NAME OFF STREET NAME         ...          \
# 1048570  LIEBIG AVENUE                                NaN         ...
# 1048571  11 STREET                                    NaN         ...
# ...

# %%
data.shape
# Out:
# (1048575, 29)

# %%
data.dtypes
# Out:
# DATE                              object
# TIME                              object
# BOROUGH                           object
# ZIP CODE                          object
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCATION                          object
# ON STREET NAME                    object
# CROSS STREET NAME                 object
# OFF STREET NAME                   object
# NUMBER OF PERSONS INJURED        float64
# NUMBER OF PERSONS KILLED         float64
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# ...

# %%
data.describe()
# Out:
#             LATITUDE      LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  929132.000000  929132.000000               1.048558e+06
# mean       40.683838     -73.861509               2.571074e-01
# std         1.283311       2.701091               6.518480e-01
# min         0.000000    -201.359990               0.000000e+00
# 25%        40.668712     -73.976502               0.000000e+00
# 50%        40.722250     -73.928580               0.000000e+00
# 75%        40.768875     -73.865760               0.000000e+00
# max        43.344444       0.000000               3.200000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              1.048545e+06                   1.048575e+06
# mean               1.080545e-03                   4.852395e-02
# std                3.479927e-02                   2.271388e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# ...

# %%
data = data.drop(columns="CONTRIBUTING FACTOR VEHICLE 3")
data = data.drop(columns="CONTRIBUTING FACTOR VEHICLE 4")
data = data.drop(columns="CONTRIBUTING FACTOR VEHICLE 5")
data = data.drop(columns="VEHICLE TYPE CODE 3")
data = data.drop(columns="VEHICLE TYPE CODE 4")
data = data.drop(columns="VEHICLE TYPE CODE 5")

# %%
data = data.drop(columns="OFF STREET NAME")

# %%
#resulting top 5 rows with removed columns
data.head()
# Out:
#       DATE  TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  3/24/19  0:00  BROOKLYN    11204  40.619130  -73.99019
# 1  3/24/19  0:00  BROOKLYN    11213  40.668648  -73.92835
# 2  3/24/19  0:00  BROOKLYN    11229  40.599144  -73.95356
# 3  3/24/19  0:00  BROOKLYN    11229  40.609130  -73.95741
# 4  3/24/19  0:00  BROOKLYN    11229  40.604027  -73.95230
#
#                  LOCATION                    ON STREET NAME CROSS STREET NAME  \
# 0   (40.61913, -73.99019)  65 STREET                                18 AVENUE
# 1  (40.668648, -73.92835)  ROCHESTER AVENUE                   EASTERN PARKWAY
# 2  (40.599144, -73.95356)  AVENUE U                            EAST 18 STREET
# 3   (40.60913, -73.95741)  EAST 16 STREET                       KINGS HIGHWAY
# 4   (40.604027, -73.9523)  OCEAN AVENUE                              AVENUE S
#
#    NUMBER OF PERSONS INJURED         ...           \
# 0                        0.0         ...
# 1                        0.0         ...
# ...

# %%
#data shape before removing rows with NaN values
data.shape
# Out:
# (1048575, 22)

# %%
#drop any rows that have at least one NaN value
data = data.dropna()

# %%
#resulting data shape
data.shape
# Out:
# (431411, 22)

# %%
data.to_csv("cleanedData.csv", index = True, encoding = "utf8")
